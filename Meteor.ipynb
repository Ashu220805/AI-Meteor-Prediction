# %%
# !pip install pandas numpy scikit-learn tensorflow joblib streamlit plotly matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\ashish\appdata\roaming\python\python312\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\ashish\appdata\roaming\python\python312\site-packages (2.3.4)
# Requirement already satisfied: scikit-learn in c:\users\ashish\appdata\roaming\python\python312\site-packages (1.6.1)
# Requirement already satisfied: tensorflow in c:\users\ashish\appdata\roaming\python\python312\site-packages (2.20.0)
# Requirement already satisfied: joblib in c:\users\ashish\appdata\roaming\python\python312\site-packages (1.5.2)
# Requirement already satisfied: streamlit in c:\users\ashish\appdata\roaming\python\python312\site-packages (1.51.0)
# Collecting plotly
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: matplotlib in c:\users\ashish\appdata\roaming\python\python312\site-packages (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8.2)
# Requirement already satisfied: pillow in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from tensorboard~=2.20.0->tensorflow) (2.2.3)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: colorama in c:\users\ashish\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=3 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.26.0)
# Requirement already satisfied: rich in c:\users\ashish\appdata\roaming\python\python312\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\ashish\appdata\roaming\python\python312\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ashish\appdata\roaming\python\python312\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ashish\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 8.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 7.5 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 7.0 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.9 MB 6.8 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 6.9 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 6.6 MB/s  0:00:01
# Installing collected packages: plotly
# Successfully installed plotly-6.4.0

# %%
# !pip install -q pandas numpy scikit-learn tensorflow joblib plotly pyarrow

import pandas as pd
import numpy as np
import joblib
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering

from sklearn.ensemble import IsolationForest

import plotly.express as px

# ---------------- Core helpers ----------------
REQUIRED_COLUMNS = ["name","id","nametype","recclass","mass","fall","year","reclat","reclong","GeoLocation","date"]

def load_data(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    missing = [c for c in REQUIRED_COLUMNS if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")
    return df

def clean_and_engineer(df: pd.DataFrame):
    df = df.copy()
    # coerce numeric
    for col in ["mass","year","reclat","reclong"]:
        df[col] = pd.to_numeric(df[col], errors="coerce")
    # drop essential NaNs
    df = df.dropna(subset=["year","reclat","reclong"])
    # mass: fill + log1p
    if df["mass"].isna().any():
        df["mass"] = df["mass"].fillna(df["mass"].median())
    df["mass_log1p"] = np.log1p(df["mass"].clip(lower=0))
    # target (not used here, but handy): Fell->1 else 0
    df["impact"] = (df["fall"].astype(str).str.strip().str.lower() == "fell").astype(int)
    features = ["year","reclat","reclong","mass_log1p"]
    return df, features

# %%
CSV_PATH = "meteor_data.csv"  # change if needed

df_raw = load_data(CSV_PATH)
df, features = clean_and_engineer(df_raw)
X = df[features].values.astype(float)

scaler = StandardScaler()
Xs = scaler.fit_transform(X)

# --- KMeans ---
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df["cluster_kmeans"] = kmeans.fit_predict(Xs)

# --- DBSCAN ---
db = DBSCAN(eps=0.8, min_samples=10).fit(Xs)
df["cluster_dbscan"] = db.labels_   # -1 means noise

# --- Agglomerative ---
ag = AgglomerativeClustering(n_clusters=5)
df["cluster_agglom"] = ag.fit_predict(Xs)

# Save artifacts
Path("artifacts").mkdir(exist_ok=True)
Path("models").mkdir(exist_ok=True)

df_out = df[["id","year","reclat","reclong","mass","mass_log1p","impact",
             "cluster_kmeans","cluster_dbscan","cluster_agglom"]].copy()

df_out.to_parquet("artifacts/clusters.parquet", index=False)
joblib.dump(kmeans, "models/kmeans.pkl")
joblib.dump(scaler, "artifacts/cluster_scaler.pkl")

print("✅ Clustering done. Saved:")
print("- artifacts/clusters.parquet")
print("- models/kmeans.pkl")
print("- artifacts/cluster_scaler.pkl")

# Quick look
df_out.head()
# Out:
# ✅ Clustering done. Saved:
# - artifacts/clusters.parquet
# - models/kmeans.pkl
# - artifacts/cluster_scaler.pkl
#     id    year    reclat    reclong      mass  mass_log1p  impact  \
# 0    1  1880.0  50.77500    6.08333      21.0    3.091042       1
# 1    2  1951.0  56.18333   10.23333     720.0    6.580639       1
# 2    6  1952.0  54.21667 -113.00000  107000.0   11.580593       1
# 3   10  1976.0  16.88333  -99.90000    1914.0    7.557473       1
# 4  370  1902.0 -33.16667  -64.95000     780.0    6.660575       1
#
#    cluster_kmeans  cluster_dbscan  cluster_agglom
# 0               2               0               0
# 1               4               0               0
# 2               2               0               0
# 3               4               0               2
# 4               2               0               0

# %%
fig = px.scatter_mapbox(
    df_out, lat="reclat", lon="reclong", color="cluster_kmeans",
    hover_name="id", zoom=1, height=500
)
fig.update_layout(mapbox_style="open-street-map")
fig.show()
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_26896\579551843.py:1: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(

# %%
USE_AUTOENCODER = True  # set to False if you want only IsolationForest

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

def build_autoencoder(input_dim: int):
    inp = Input(shape=(input_dim,))
    x = Dense(16, activation="relu")(inp)
    x = Dense(8, activation="relu")(x)
    bottleneck = Dense(4, activation="relu")(x)
    x = Dense(8, activation="relu")(bottleneck)
    x = Dense(16, activation="relu")(x)
    out = Dense(input_dim, activation="linear")(x)
    ae = Model(inp, out)
    ae.compile(optimizer="adam", loss="mse")
    return ae

# Use same features & scaler style, but fit a fresh scaler for anomalies
sc_anom = StandardScaler()
Xs_anom = sc_anom.fit_transform(df[features].values.astype(float))

# --- Isolation Forest ---
iso = IsolationForest(contamination=0.02, random_state=42)
iso.fit(Xs_anom)
iso_scores = -iso.score_samples(Xs_anom)  # higher => more anomalous

# --- Autoencoder (optional) ---
if USE_AUTOENCODER:
    ae = build_autoencoder(Xs_anom.shape[1])
    ae.fit(Xs_anom, Xs_anom, epochs=50, batch_size=32, validation_split=0.2, verbose=0)
    recon = ae.predict(Xs_anom, verbose=0)
    recon_err = ((Xs_anom - recon)**2).mean(axis=1)
else:
    ae = None
    recon_err = np.zeros(len(Xs_anom))

# Save artifacts
joblib.dump(iso, "models/isolation_forest.pkl")
joblib.dump(sc_anom, "artifacts/anomaly_scaler.pkl")
if ae is not None:
    ae.save("models/autoencoder.keras")

anom = df[["id","year","reclat","reclong","mass"]].copy()
anom["iso_anomaly_score"] = iso_scores
anom["ae_recon_error"] = recon_err
anom.to_parquet("artifacts/anomaly_scores.parquet", index=False)

print("✅ Anomaly detection done. Saved:")
print("- models/isolation_forest.pkl")
if ae is not None:
    print("- models/autoencoder.keras")
print("- artifacts/anomaly_scores.parquet")

# Show top anomalies
anom.sort_values(["iso_anomaly_score","ae_recon_error"], ascending=False).head(20)
# Out:
# ✅ Anomaly detection done. Saved:
# - models/isolation_forest.pkl
# - models/autoencoder.keras
# - artifacts/anomaly_scores.parquet
#           id    year    reclat    reclong        mass  iso_anomaly_score  \
# 17215  12356  1749.0  54.90000   91.80000    700000.0           0.751667
# 5308    5262  1818.0  76.13333  -64.93333  58200000.0           0.739378
# 31750  18884  1797.0  -7.56667  110.83333    500000.0           0.733266
# 5137    5130  1810.0  52.50000   30.33333    823000.0           0.731278
# 37401  23694  1873.0  58.61667   98.93333    217000.0           0.727721
# 16434  12025  1822.0 -24.20333  -68.80667    920000.0           0.726622
# 5023    5015  1784.0 -10.11667  -39.20000   5360000.0           0.724716
# 972    24004  1807.0  54.50000   35.20000     65500.0           0.722426
# 985    24037  1824.0  51.73333  102.53333      2000.0           0.722325
# 37905  24166  1854.0  54.76667  113.98333     18000.0           0.721175
# 251     7718  1805.0  51.20000  112.30000      3891.0           0.720301
# 5546    5463  1854.0 -38.10000  145.30000   8600000.0           0.720198
# 461    12286  1850.0  38.98333  141.61667    135000.0           0.720142
# 5307    5261  1793.0 -33.50000   26.00000    136000.0           0.719656
# 21503  14695  1781.0  29.30000  105.30000    158500.0           0.718920
# 4974    4951  1845.0 -35.30000  144.56667    200000.0           0.718738
# 16449  12047  1869.0  53.00000 -112.00000    175000.0           0.717591
# 5066    5062  1805.0  49.96667    6.53333   1500000.0           0.717329
# 26206  16949  1846.0  54.23333   35.15000    250000.0           0.715999
# 12543  10912  1836.0 -25.50000   18.00000  26000000.0           0.715572
#
#        ae_recon_error
# 17215        0.082241
# 5308         0.237998
# 31750        0.028839
# 5137         0.058646
# 37401        0.136667
# 16434        0.394236
# 5023         0.250710
# 972          0.063041
# 985          0.060403
# 37905        0.097161
# 251          0.066170
# 5546         0.035303
# 461          0.189078
# 5307         0.790663
# 21503        0.052329
# 4974         0.041830
# 16449        0.053734
# 5066         0.041806
# 26206        0.078905
# 12543        0.491066

# %%
fig = px.scatter(
    anom, x="iso_anomaly_score", y="ae_recon_error",
    hover_data=["id","year","mass"], title="Anomaly Space"
)
fig.show()

# %%
# !streamlit run app.py --server.port 8501
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.104:8501
# c:\Users\Ashish\OneDrive\Documents\Desktop\Basic Projects\meteor_ml\app.py:72: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(
# 2025-11-10 22:00:06.703 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-11-10 22:00:06.848 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# c:\Users\Ashish\OneDrive\Documents\Desktop\Basic Projects\meteor_ml\app.py:72: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#
# 2025-11-10 22:00:50.319 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-11-10 22:00:50.423 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
